# %%
class Father:
    def skills(self):
        return "skills:Scientist"

class Mother:
    def skills(self):
        return "skills:Freelancer"

class Child(Father,Mother):
    def skills(self):
        return  "skills : Scientist and Freelancer"

# %%
s = Child()
print(s.skills())
# Out:
# skills : Scientist and Freelancer
