# %%
import numpy as np

# %%
import time

# %%
#list and numpy
list1 =[i for i in range(10000)]
array = np.arange(10000)

#multiply each elemet by 5 
start = time.time()
list_result = [x * 5 for x in list1]
end = time.time()
print("list timining:",end - start)
# Out:
# list timining: 0.0

# %%
# multiply eash elemet by 5 in numpy
start = time.time()
array_result = array*5
end = time.time()
print("numpy timing:", end -start)
# Out:
# numpy timing: 0.012350082397460938

# %%
# numpy is faster ,because it made of c language
